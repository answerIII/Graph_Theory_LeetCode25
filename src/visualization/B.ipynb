# %%
import pandas as pd
import re
from collections import defaultdict

filepath = r'..\graph\landmarkAlgo\benchmark\output\Wiki-Vote-landmarkShortcut-bench.txt'

with open(filepath, 'r') as f:
    lines = f.readlines()

results = defaultdict(dict)

current_algorithm = None
current_landmarks = None

for line in lines:
    line = line.strip()

    if line.startswith('graph_theory/graph/landmarkAlgo'):
        current_algorithm = line.split('.')[-1]

    elif line.startswith('landmarks:'):
        current_landmarks = int(re.search(r'\d+', line).group())

    elif current_algorithm and current_landmarks:
        if line.startswith('precomputing time:'):
            results[(current_landmarks, 'precomputing time (ms)')][current_algorithm] = int(re.search(r'\d+', line).group())
        elif line.startswith('Avg actual distance time:'):
            results[(current_landmarks, 'Avg actual distance time')][current_algorithm] = float(re.search(r'\d+\.\d+', line).group())
        elif line.startswith('Mean absolute error:'):
            results[(current_landmarks, 'Mean absolute error')][current_algorithm] = float(re.search(r'\d+\.\d+', line).group())
        elif line.startswith('Avg estimated distance time:'):
            results[(current_landmarks, 'Avg estimated distance time')][current_algorithm] = float(re.search(r'\d+\.\d+', line).group())
        elif line.startswith('file size:'):
            results[(current_landmarks, 'file size (MB)')][current_algorithm] = float(re.search(r'\d+\.\d+', line).group())

df = pd.DataFrame(results).T
df.index.names = ['landmarks', 'metric']
df = df.sort_index()

df
# Out:
#                                        SelectRandomNodes  SelectHighestDegree  \
# landmarks metric
# 4         Avg actual distance time                1.0400               0.9600
#           Avg estimated distance time             0.0000               0.0000
#           Mean absolute error                     0.3030               0.2000
#           file size (MB)                          0.1100               0.1100
#           precomputing time (ms)                  7.0000              10.0000
# 8         Avg actual distance time                1.0100               0.9700
#           Avg estimated distance time             0.0000               0.0000
#           Mean absolute error                     0.0707               0.1134
#           file size (MB)                          0.2200               0.2200
#           precomputing time (ms)                 10.0000              12.0000
# 16        Avg actual distance time                1.0900               1.1300
#           Avg estimated distance time             0.0000               0.0000
#           Mean absolute error                     0.0510               0.1100
#           file size (MB)                          0.4300               0.4300
#           precomputing time (ms)                 16.0000              17.0000
# 32        Avg actual distance time                1.1000               1.2500
#           Avg estimated distance time             0.0000               0.0100
#           Mean absolute error                     0.0202               0.0202
#           file size (MB)                          0.8700               0.8700
#           precomputing time (ms)                 28.0000              29.0000
# 64        Avg actual distance time                1.0000               0.9800
#           Avg estimated distance time             0.0400               0.0300
#           Mean absolute error                     0.0000               0.0202
#           file size (MB)                          1.7400               1.7400
#           precomputing time (ms)                 51.0000              53.0000
# 128       Avg actual distance time                1.1500               1.0200
#           Avg estimated distance time             1.0200               0.8500
#           Mean absolute error                     0.0000               0.0103
#           file size (MB)                          3.4700               3.4700
#           precomputing time (ms)                 99.0000             101.0000
#
#                                        SelectBestCoverage
# landmarks metric
# 4         Avg actual distance time                 1.0300
#           Avg estimated distance time              0.0000
#           Mean absolute error                      0.3367
#           file size (MB)                           0.1100
#           precomputing time (ms)                 180.0000
# 8         Avg actual distance time                 0.9900
#           Avg estimated distance time              0.0000
#           Mean absolute error                      0.2449
#           file size (MB)                           0.2200
#           precomputing time (ms)                 177.0000
# 16        Avg actual distance time                 0.9300
#           Avg estimated distance time              0.0000
#           Mean absolute error                      0.1200
#           file size (MB)                           0.4300
#           precomputing time (ms)                 194.0000
# 32        Avg actual distance time                 1.0300
#           Avg estimated distance time              0.0000
#           Mean absolute error                      0.0612
#           file size (MB)                           0.8700
#           precomputing time (ms)                 207.0000
# 64        Avg actual distance time                 1.1100
#           Avg estimated distance time              0.0500
#           Mean absolute error                      0.0204
#           file size (MB)                           1.7400
#           precomputing time (ms)                 226.0000
# 128       Avg actual distance time                 1.0500
#           Avg estimated distance time              1.0000
#           Mean absolute error                      0.0204
#           file size (MB)                           3.4700
#           precomputing time (ms)                 275.0000
